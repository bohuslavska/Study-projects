# %% [markdown]
# **About this project**
#
# This project aimed at scraping some news articles from a multidisciplinary science journal *Nature* using the Beautiful Soup library, summarizing them with a transformer model T5 Large, creating a dataset, and storing it in an SQLite database.

# %%
#Installations

# !pip install selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# !pip -q install transformers

# %%
#Imports

import requests
from bs4 import BeautifulSoup
import string
import os
from transformers import pipeline
import torch
import pandas as pd
pd.set_option('display.max_colwidth', 500)
import sqlite3

# %%
#Let's use T5 Large model for the summarization.

summarizer = pipeline("summarization", model="t5-large", tokenizer="t5-large", framework="pt")
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-large automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
#Let's find out the general amount of pages for scraping.

start_link = f'https://www.nature.com/nature/articles?type=news&year=2023'
content = requests.get(start_link).text
soup = BeautifulSoup(content, "html.parser")
last_page_index = -2
pagination = soup.find_all('li', class_='c-pagination__item')[last_page_index].get_text().strip()
page_number = [i for i in pagination if i in list(string.digits)]
page_number = int(''.join(page_number))
page_number
# Out:
# 10

# %%
#Iterating through all the pages dedicated to 2023 news.

list_scraped = []

for u in range(1, page_number+1): 
    
    URL = f'https://www.nature.com/nature/articles?searchType=journalSearch&sort=PubDate&type=news&year=2023&page={u}'
    content = requests.get(URL).text
    soup = BeautifulSoup(content, "html.parser")

    publications = soup.find_all('li', class_='app-article-list-row__item') 

    for publication in publications: 
        title = publication.find('h3', class_= 'c-card__title').text.strip()
        text = publication.find('div', class_= 'c-article-body main-content')
        prelink = publication.find('a', {'data-track-action':'view article'}).get('href')
        article_link = 'https://www.nature.com' + prelink
        URL2 = article_link
        response = requests.get(URL2).text
        soup = BeautifulSoup(response, "html.parser")
        try:
            text_article = soup.find('div', class_='c-article-body main-content').text.strip()
            summary = summarizer(text_article)
            summary = summary[0]['summary_text']
            article ={"title": title, "link": article_link, "summary": summary}
            list_scraped.append(article)
        except Exception:
            continue
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1435 > 512). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1219: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(

# %%
#We can notice that a lot of news is behind a paywall. 
#However, we still managed to scrape some up-to-date scientific data.
#Now let's create a dataset with the scraped news.

df = pd.DataFrame(list_scraped)
df
# Out:
#                                                                                  title  \
# 0         Editors quit top neuroscience journal to protest against open-access charges
# 1               Genetic map of Tasmanian devil cancers hints at their future evolution
# 2              White House to tap cancer leader Monica Bertagnolli as new NIH director
# 3                                Drugs give biology’s favourite worms the munchies too
# 4        Australian researchers welcome plan to curb politicians’ power to veto grants
# 5                         Comb jellies’ unique fused neurons challenge evolution ideas
# 6                   SpaceX Starship: launch of biggest-ever rocket ends with explosion
# 7                              Racial inequalities deepened in US prisons during COVID
# 8                   Famous ‘homunculus’ brain map redrawn to include complex movements
# 9                         Why Earth’s giant kelp forests are worth $500 billion a year
# 10                                How a rural school teacher became a top COVID sleuth
# 11  ‘Democracy in microscopy’: cheap light microscope delivers super-resolution images
# 12                         Mega rocket Starship could enable new types of astrophysics
# 13              AI science search engines are exploding in number — are they any good?
# 14                              Massive mosquito factory in Brazil aims to halt dengue
# 15                                     Tonga volcano eruption triggered ‘mega-tsunami’
# 16                       Jupiter mission will be first to orbit moon of another planet
# 17  Death threats, trolling and sexist abuse: climate scientists report online attacks
# 18             Global scholars decry funding ban on influential Indian research centre
# 19                                    Stem-cell-derived ‘embryos’ implanted in monkeys
# 20             Medieval accounts of eclipses shine light on massive volcanic eruptions
# 21                          How air pollution causes lung cancer — without harming DNA
# 22                          What Chernobyl’s stray dogs could teach us about radiation
# 23          WHO abandons plans for crucial second phase of COVID-origins investigation
#
#                                                   link  \
# 0   https://www.nature.com/articles/d41586-023-01391-5
# 1   https://www.nature.com/articles/d41586-023-01349-7
# 2   https://www.nature.com/articles/d41586-023-01378-2
# 3   https://www.nature.com/articles/d41586-023-01376-4
# 4   https://www.nature.com/articles/d41586-023-01379-1
# 5   https://www.nature.com/articles/d41586-023-01381-7
# 6   https://www.nature.com/articles/d41586-023-01377-3
# 7   https://www.nature.com/articles/d41586-023-01311-7
# 8   https://www.nature.com/articles/d41586-023-01312-6
# 9   https://www.nature.com/articles/d41586-023-01307-3
# 10  https://www.nature.com/articles/d41586-023-01047-4
# 11  https://www.nature.com/articles/d41586-023-01267-8
# 12  https://www.nature.com/articles/d41586-023-01306-4
# 13  https://www.nature.com/articles/d41586-023-01273-w
# 14  https://www.nature.com/articles/d41586-023-01266-9
# 15  https://www.nature.com/articles/d41586-023-01272-x
# 16  https://www.nature.com/articles/d41586-023-01256-x
# 17  https://www.nature.com/articles/d41586-023-01018-9
# 18  https://www.nature.com/articles/d41586-023-00995-1
# 19  https://www.nature.com/articles/d41586-023-00996-0
# 20  https://www.nature.com/articles/d41586-023-00939-9
# 21  https://www.nature.com/articles/d41586-023-00989-z
# 22  https://www.nature.com/articles/d41586-023-00629-6
# 23  https://www.nature.com/articles/d41586-023-00283-y
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       summary
# 0                                                                                                                                                                                                       more than 40 editors have resigned from two leading neuroscience journals in protest . they say that the fees, which publishers use to cover publishing services and in some cases make money, are unethical . the editors plan to start a new journal hosted by the non-profit publisher MIT Press .
# 1                                                                                                                                                                                                                                                                                 Tasmanian devils are susceptible to two cancers that are spread by biting . genetic analysis of these cancers has tracked their evolution . lays the groundwork for modelling how they could affect populations in future .
# 2                                                                                                                                                                                                                                             if confirmed by the US Senate, Bertagnolli will take over the NIH . the agency has a budget of more than US$47 billion and is composed of 27 separate institutes and centres . it has taken more than a year to find geneticist Francis Collins's replacement .
# 3                                                                                                                                                                         study suggests mechanism by which cannabis affects appetite evolved more than 500 million years ago . cannabinoid molecules derived from cannabis plant bind to same receptors as molecules naturally found in the body . researchers tested endocannabinoids on worms genetically engineered to have human cannabinoid receptors .
# 4                                                                                                                                                                 researchers in australia have previously criticized political interference in the grant-awarding process . the changes were recommended on 20 April as part of an independent review into the legislation underpinning the Australian Research Council . acting education minister Stuart Robert vetoed six ARC projects in December 2021 .
# 5                                                                                                                                                                                                                                                        ctenophores, also known as comb jellies, have a fused network of neurons . scientists used an electron microscope to create a 3D reconstruction of the nervous system . the results suggest that the animal's nervous system evolved independently .
# 6                                                                                                                                                                 Starship roared off a launch pad in southern texas today and then exploded before it reached space . the goal of today's flight had been to reach space and travel most of the way around the planet . if spaceX demonstrates that Starship can reach orbit, that will be "significant for what it will bring afterwards", says an expert .
# 7                                                                                                                                                    researchers compiled 20 years' worth of demographic records on prison populations . they found that the proportion of incarcerated Black people had been decreasing . but by the end of 2021, the proportion who were Black had returned to pre-pandemic levels . the researchers hope their findings will help to reshape the criminal justice system .
# 8                                                                                                                                                                                                                           a new study redraws the motor homunculus or 'little man' diagram . it adds regions connected to brain areas responsible for coordinating complex movements . the findings could lead to changes in therapy for disorders of the primary motor cortex caused by stroke or injury .
# 9                                                                                                                                                    kelp forests provide services worth between $465 billion and $562 billion a year . they provide habitat for more than 1,000 species, draw carbon dioxide from the atmosphere . each hectare removes an average of 657 kilograms of excess nitrogen from seawater . pollack, giant seabass, south american morwongs and lingcod were most valuable fish .
# 10                                                                                                         a motley crew of self-taught ‘community scientists’ spend hours poring through genetic sequences to track SARS-CoV-2's evolution . virologists from all over the world have attracted the attention of prominent scientists for their uncanny ability to detect unusual mutations . without community scientists, new variants would go under the radar for a little longer, says one virologist .
# 11                                                                                                      researchers have developed a method for ordinary light microscopes that they hope will demolish such barriers . the technique, dubbed ONE microscopy, offers a level of detail that eclipses even that of multi-million-dollar ‘super-resolution’ microscopes . researchers have used their approach to record jaw-dropping images of individual proteins and never-before-seen structures in cells .
# 12                                                                                                                                                                              if successful, the first test flight will make Starship the most powerful rocket ever to leave Earth’s surface . the spaceship is nearly twice as powerful as NASA’s new mega rocket, the Space Launch System . scientists say that Starship could enable new types of mission, including crewed and uncrewed trips to Mars .
# 13                                                                                                                                                                                                   several AI search engines aim to make it easier for researchers to grasp seminal scientific papers . developers claim the apps will democratize and streamline access to research . but some tools need more refinement before researchers can use them, say scientists who have experimented with them.
# 14                                                                                                                                                                                                                                             modified mosquitoes will be released in many of Brazil's urban areas over next 10 years . the aim is to protect up to 70 million people from diseases such as dengue . a mosquito factory will be built in a location yet to be determined in Rio de Janeiro .
# 15                                                                                                                                     study shows that the blast generated waves that towered more than 40 metres high along some of tonga’s coastlines . tsunamis triggered in this way are difficult to monitor because they move faster than those caused by earthquakes or landslides . vast, shallow reef platforms in the Tonga Archipelago probably shaped the height and flow of the tsunami waves .
# 16                                                                                                       the european space agency is preparing to launch a mission to Jupiter . the probe will get close to three of the four large moons Galileo discovered . it will eventually circle around the largest, Ganymede, and search for evidence of a hidden ocean beneath its icy surface . if successful, it will be the first time any spacecraft has orbited a natural satellite other than Earth’s Moon .
# 17                                                                                                                                                                                                                             survey by global witness hints at the extent of online abuse faced by scientists . many respondents reported anxiety, sleeping problems or a loss of productivity . 34% of female climate scientists who experienced abuse said they had received attacks relating to gender .
# 18                                                                                                                                                                                                                                       Indian government suspends foreign funding to Indian think tank the Centre for Policy Research . move has sparked an outcry among Indian and foreign researchers . they fear the suspension could cripple the think tank and muzzle independent scrutiny of policy .
# 19                                                                                                                                              scientists have created balls of cells that resemble the early stages of an embryo . the stem-cell-derived blastoids could help researchers understand human embryo development without the ethical dilemmas of using real embryonic cells . cynomolgus monkeys are commonly used as lab animals because they have some biological similarities with humans .
# 20                                                                                                                                            palaeoclimatologists have used medieval accounts of lunar eclipses to help pin down the timing and impact of volcanic eruptions from 1100 to 13001 . the new record aligns with earlier estimates based on dust layers found in ice cores from Antarctica and greenland . knowing the precise timing of eruptions can help scientists to improve their models .
# 21                                                                                                                                                                                                                                                                             air pollution could cause lung cancer by creating an inflamed environment . air pollution causes millions of deaths worldwide each year . study could lead to ways to prevent other cancers caused by environmental exposure .
# 22  DNA collected from feral dogs living near the power plant reveals they are descendants of dogs that were either present at the time of the accident or settled in the area shortly afterwards . researchers hope to use the knowledge gained to better understand the effects of long-term radiation exposure on human genetics and health . the study is the first step in a larger project aimed at understanding how the dogs have adapted to survive in one of the most radioactive places on earth .
# 23                                                                                                                                                                                                              the WHO has quietly shelved the second phase of its COVID-19 origins investigation . a team of experts travelled to Wuhan in february 2020 to review evidence on when and how the virus might have emerged . without access to china, there is little the WHO can do to advance the studies .

# %%
#Writing the dataset to the SQLite database on Google Drive.

from google.colab import drive
drive.mount('/content/gdrive/')
# %cd '/content/gdrive/MyDrive/ML_projects'

conn = sqlite3.connect('scraped_news.sqlite')
df.to_sql('data_news', conn, if_exists='replace', index=False)
conn.close()
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/ML_projects

# %%
#Check

conn = sqlite3.connect('scraped_news.sqlite')
df = pd.read_sql_query('SELECT * FROM data_news', conn)
conn.close()
df
# Out:
#                                                                                  title  \
# 0         Editors quit top neuroscience journal to protest against open-access charges
# 1               Genetic map of Tasmanian devil cancers hints at their future evolution
# 2              White House to tap cancer leader Monica Bertagnolli as new NIH director
# 3                                Drugs give biology’s favourite worms the munchies too
# 4        Australian researchers welcome plan to curb politicians’ power to veto grants
# 5                         Comb jellies’ unique fused neurons challenge evolution ideas
# 6                   SpaceX Starship: launch of biggest-ever rocket ends with explosion
# 7                              Racial inequalities deepened in US prisons during COVID
# 8                   Famous ‘homunculus’ brain map redrawn to include complex movements
# 9                         Why Earth’s giant kelp forests are worth $500 billion a year
# 10                                How a rural school teacher became a top COVID sleuth
# 11  ‘Democracy in microscopy’: cheap light microscope delivers super-resolution images
# 12                         Mega rocket Starship could enable new types of astrophysics
# 13              AI science search engines are exploding in number — are they any good?
# 14                              Massive mosquito factory in Brazil aims to halt dengue
# 15                                     Tonga volcano eruption triggered ‘mega-tsunami’
# 16                       Jupiter mission will be first to orbit moon of another planet
# 17  Death threats, trolling and sexist abuse: climate scientists report online attacks
# 18             Global scholars decry funding ban on influential Indian research centre
# 19                                    Stem-cell-derived ‘embryos’ implanted in monkeys
# 20             Medieval accounts of eclipses shine light on massive volcanic eruptions
# 21                          How air pollution causes lung cancer — without harming DNA
# 22                          What Chernobyl’s stray dogs could teach us about radiation
# 23          WHO abandons plans for crucial second phase of COVID-origins investigation
#
#                                                   link  \
# 0   https://www.nature.com/articles/d41586-023-01391-5
# 1   https://www.nature.com/articles/d41586-023-01349-7
# 2   https://www.nature.com/articles/d41586-023-01378-2
# 3   https://www.nature.com/articles/d41586-023-01376-4
# 4   https://www.nature.com/articles/d41586-023-01379-1
# 5   https://www.nature.com/articles/d41586-023-01381-7
# 6   https://www.nature.com/articles/d41586-023-01377-3
# 7   https://www.nature.com/articles/d41586-023-01311-7
# 8   https://www.nature.com/articles/d41586-023-01312-6
# 9   https://www.nature.com/articles/d41586-023-01307-3
# 10  https://www.nature.com/articles/d41586-023-01047-4
# 11  https://www.nature.com/articles/d41586-023-01267-8
# 12  https://www.nature.com/articles/d41586-023-01306-4
# 13  https://www.nature.com/articles/d41586-023-01273-w
# 14  https://www.nature.com/articles/d41586-023-01266-9
# 15  https://www.nature.com/articles/d41586-023-01272-x
# 16  https://www.nature.com/articles/d41586-023-01256-x
# 17  https://www.nature.com/articles/d41586-023-01018-9
# 18  https://www.nature.com/articles/d41586-023-00995-1
# 19  https://www.nature.com/articles/d41586-023-00996-0
# 20  https://www.nature.com/articles/d41586-023-00939-9
# 21  https://www.nature.com/articles/d41586-023-00989-z
# 22  https://www.nature.com/articles/d41586-023-00629-6
# 23  https://www.nature.com/articles/d41586-023-00283-y
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       summary
# 0                                                                                                                                                                                                       more than 40 editors have resigned from two leading neuroscience journals in protest . they say that the fees, which publishers use to cover publishing services and in some cases make money, are unethical . the editors plan to start a new journal hosted by the non-profit publisher MIT Press .
# 1                                                                                                                                                                                                                                                                                 Tasmanian devils are susceptible to two cancers that are spread by biting . genetic analysis of these cancers has tracked their evolution . lays the groundwork for modelling how they could affect populations in future .
# 2                                                                                                                                                                                                                                             if confirmed by the US Senate, Bertagnolli will take over the NIH . the agency has a budget of more than US$47 billion and is composed of 27 separate institutes and centres . it has taken more than a year to find geneticist Francis Collins's replacement .
# 3                                                                                                                                                                         study suggests mechanism by which cannabis affects appetite evolved more than 500 million years ago . cannabinoid molecules derived from cannabis plant bind to same receptors as molecules naturally found in the body . researchers tested endocannabinoids on worms genetically engineered to have human cannabinoid receptors .
# 4                                                                                                                                                                 researchers in australia have previously criticized political interference in the grant-awarding process . the changes were recommended on 20 April as part of an independent review into the legislation underpinning the Australian Research Council . acting education minister Stuart Robert vetoed six ARC projects in December 2021 .
# 5                                                                                                                                                                                                                                                        ctenophores, also known as comb jellies, have a fused network of neurons . scientists used an electron microscope to create a 3D reconstruction of the nervous system . the results suggest that the animal's nervous system evolved independently .
# 6                                                                                                                                                                 Starship roared off a launch pad in southern texas today and then exploded before it reached space . the goal of today's flight had been to reach space and travel most of the way around the planet . if spaceX demonstrates that Starship can reach orbit, that will be "significant for what it will bring afterwards", says an expert .
# 7                                                                                                                                                    researchers compiled 20 years' worth of demographic records on prison populations . they found that the proportion of incarcerated Black people had been decreasing . but by the end of 2021, the proportion who were Black had returned to pre-pandemic levels . the researchers hope their findings will help to reshape the criminal justice system .
# 8                                                                                                                                                                                                                           a new study redraws the motor homunculus or 'little man' diagram . it adds regions connected to brain areas responsible for coordinating complex movements . the findings could lead to changes in therapy for disorders of the primary motor cortex caused by stroke or injury .
# 9                                                                                                                                                    kelp forests provide services worth between $465 billion and $562 billion a year . they provide habitat for more than 1,000 species, draw carbon dioxide from the atmosphere . each hectare removes an average of 657 kilograms of excess nitrogen from seawater . pollack, giant seabass, south american morwongs and lingcod were most valuable fish .
# 10                                                                                                         a motley crew of self-taught ‘community scientists’ spend hours poring through genetic sequences to track SARS-CoV-2's evolution . virologists from all over the world have attracted the attention of prominent scientists for their uncanny ability to detect unusual mutations . without community scientists, new variants would go under the radar for a little longer, says one virologist .
# 11                                                                                                      researchers have developed a method for ordinary light microscopes that they hope will demolish such barriers . the technique, dubbed ONE microscopy, offers a level of detail that eclipses even that of multi-million-dollar ‘super-resolution’ microscopes . researchers have used their approach to record jaw-dropping images of individual proteins and never-before-seen structures in cells .
# 12                                                                                                                                                                              if successful, the first test flight will make Starship the most powerful rocket ever to leave Earth’s surface . the spaceship is nearly twice as powerful as NASA’s new mega rocket, the Space Launch System . scientists say that Starship could enable new types of mission, including crewed and uncrewed trips to Mars .
# 13                                                                                                                                                                                                   several AI search engines aim to make it easier for researchers to grasp seminal scientific papers . developers claim the apps will democratize and streamline access to research . but some tools need more refinement before researchers can use them, say scientists who have experimented with them.
# 14                                                                                                                                                                                                                                             modified mosquitoes will be released in many of Brazil's urban areas over next 10 years . the aim is to protect up to 70 million people from diseases such as dengue . a mosquito factory will be built in a location yet to be determined in Rio de Janeiro .
# 15                                                                                                                                     study shows that the blast generated waves that towered more than 40 metres high along some of tonga’s coastlines . tsunamis triggered in this way are difficult to monitor because they move faster than those caused by earthquakes or landslides . vast, shallow reef platforms in the Tonga Archipelago probably shaped the height and flow of the tsunami waves .
# 16                                                                                                       the european space agency is preparing to launch a mission to Jupiter . the probe will get close to three of the four large moons Galileo discovered . it will eventually circle around the largest, Ganymede, and search for evidence of a hidden ocean beneath its icy surface . if successful, it will be the first time any spacecraft has orbited a natural satellite other than Earth’s Moon .
# 17                                                                                                                                                                                                                             survey by global witness hints at the extent of online abuse faced by scientists . many respondents reported anxiety, sleeping problems or a loss of productivity . 34% of female climate scientists who experienced abuse said they had received attacks relating to gender .
# 18                                                                                                                                                                                                                                       Indian government suspends foreign funding to Indian think tank the Centre for Policy Research . move has sparked an outcry among Indian and foreign researchers . they fear the suspension could cripple the think tank and muzzle independent scrutiny of policy .
# 19                                                                                                                                              scientists have created balls of cells that resemble the early stages of an embryo . the stem-cell-derived blastoids could help researchers understand human embryo development without the ethical dilemmas of using real embryonic cells . cynomolgus monkeys are commonly used as lab animals because they have some biological similarities with humans .
# 20                                                                                                                                            palaeoclimatologists have used medieval accounts of lunar eclipses to help pin down the timing and impact of volcanic eruptions from 1100 to 13001 . the new record aligns with earlier estimates based on dust layers found in ice cores from Antarctica and greenland . knowing the precise timing of eruptions can help scientists to improve their models .
# 21                                                                                                                                                                                                                                                                             air pollution could cause lung cancer by creating an inflamed environment . air pollution causes millions of deaths worldwide each year . study could lead to ways to prevent other cancers caused by environmental exposure .
# 22  DNA collected from feral dogs living near the power plant reveals they are descendants of dogs that were either present at the time of the accident or settled in the area shortly afterwards . researchers hope to use the knowledge gained to better understand the effects of long-term radiation exposure on human genetics and health . the study is the first step in a larger project aimed at understanding how the dogs have adapted to survive in one of the most radioactive places on earth .
# 23                                                                                                                                                                                                              the WHO has quietly shelved the second phase of its COVID-19 origins investigation . a team of experts travelled to Wuhan in february 2020 to review evidence on when and how the virus might have emerged . without access to china, there is little the WHO can do to advance the studies .
