# %% [markdown]
# <a href="https://colab.research.google.com/github/bohuslavska/Study-projects/blob/main/Web_Scraper_and_Summarizer(BeautifulSoup%2CTransformer%2CSQLite)/Web_Scraper_and_Summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **About this project**
#
# This project aimed at scraping some news articles from a multidisciplinary science journal *Nature* using the Beautiful Soup library, summarizing them with a transformer model T5 Large, creating a dataset, and storing it in an SQLite database.

# %%
#Installations

# !pip install selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# !pip -q install transformers

# %%
#Imports

import requests
from bs4 import BeautifulSoup
import string
import os
from transformers import pipeline
import torch
import pandas as pd
import sqlite3

# %%
# Let's use T5 Large model for the summarization.

summarizer = pipeline("summarization", model="t5-large", tokenizer="t5-large", framework="pt")
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-large automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(

# %%
#Iterating through several pages dedicated to 2023 news.

list_scraped = []
for u in range(1,3): 
    
    URL = f'https://www.nature.com/nature/articles?searchType=journalSearch&sort=PubDate&type=news&year=2023&page={u}'
    content = requests.get(URL).text
    soup = BeautifulSoup(content, "html.parser")
    
    publications = soup.find_all('li', class_='app-article-list-row__item')  

    for publication in publications: 
        title = publication.find('h3', class_= 'c-card__title').text.strip()
        text = publication.find('div', class_= 'c-article-body main-content')
        prelink = publication.find('a', {'data-track-action':'view article'}).get('href')
        article_link = 'https://www.nature.com' + prelink
        URL2 = article_link
        response = requests.get(URL2).text
        soup = BeautifulSoup(response, "html.parser")

        try:
            text_article = soup.find('div', class_='c-article-body main-content').text.strip()
            sum = summarizer(text_article)
            sum = sum[0]['summary_text']
            article ={"title": title, "link": article_link, "summary": sum}
            list_scraped.append(article)
        except:
            continue
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (623 > 512). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(

# %%
#Creating the dataset with the scraped news.

df = pd.DataFrame(list_scraped)
df.head(10)
# Out:
#                                                title  \
# 0  Death threats, trolling and sexist abuse: clim...
# 1  Crazy ants’ strange genomes are a biological f...
# 2  Researchers back African Union to join G20 gro...
# 3  Global scholars decry funding ban on influenti...
# 4   Stem-cell derived ‘embryos’ implanted in monkeys
# 5  COVID-origins data from Wuhan market published...
# 6  Medieval accounts of eclipses shine light on m...
# 7  How air pollution causes lung cancer — without...
# 8  Habit-linked brain circuits light up in people...
# 9  How virtual models of the brain could transfor...
#
#                                                 link  \
# 0  https://www.nature.com/articles/d41586-023-010...
# 1  https://www.nature.com/articles/d41586-023-010...
# 2  https://www.nature.com/articles/d41586-023-010...
# 3  https://www.nature.com/articles/d41586-023-009...
# 4  https://www.nature.com/articles/d41586-023-009...
# 5  https://www.nature.com/articles/d41586-023-009...
# 6  https://www.nature.com/articles/d41586-023-009...
# 7  https://www.nature.com/articles/d41586-023-009...
# 8  https://www.nature.com/articles/d41586-023-009...
# 9  https://www.nature.com/articles/d41586-023-009...
#
#                                              summary
# 0  survey by non-governmental organization Global...
# 1  yellow crazy ants are a notorious invasive spe...
# 2  researchers are backing the inclusion of the A...
# 3  Indian government suspends foreign funding to ...
# 4  stem-cell-derived blastoids could help researc...
# 5  researchers have published an analysis of swab...
# 6  palaeoclimatologists have used medieval accoun...
# 7  air pollution could cause lung cancer by creat...
# 8  brain scans of people with binge-eating disord...
# 9  virtual models representing brains of people w...

# %%
#Writing the dataset to the SQLite database on Google Drive.

from google.colab import drive
drive.mount('/content/gdrive/')
# %cd '/content/gdrive/MyDrive/ML_projects'

conn = sqlite3.connect('scraped_news.sqlite')
df.to_sql('data_news', conn, if_exists='replace', index=False)
conn.close()
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/ML_projects

# %%
#Check

conn = sqlite3.connect('scraped_news.sqlite')
df = pd.read_sql_query('SELECT * FROM data_news', conn)
conn.close()
df
# Out:
#                                                 title  \
# 0   Death threats, trolling and sexist abuse: clim...
# 1   Crazy ants’ strange genomes are a biological f...
# 2   Researchers back African Union to join G20 gro...
# 3   Global scholars decry funding ban on influenti...
# 4    Stem-cell derived ‘embryos’ implanted in monkeys
# 5   COVID-origins data from Wuhan market published...
# 6   Medieval accounts of eclipses shine light on m...
# 7   How air pollution causes lung cancer — without...
# 8   Habit-linked brain circuits light up in people...
# 9   How virtual models of the brain could transfor...
# 10  Mars rocks await a ride to Earth — can NASA de...
# 11       Light waves squeezed through ‘slits in time’
# 12  ‘This shouldn’t be happening’: levels of banne...
# 13  Ancient DNA illuminates Swahili culture’s origins
# 14  Long COVID exercise trials proposed by NIH rai...
# 15  3D-printable glass is made from proteins and b...
# 16  Facelift for T. rex: analysis suggests teeth w...
# 17  Stressed plants ‘cry’ — and some animals can p...
# 18  AI ‘fairness’ research held back by lack of di...
# 19  Could grinding up lithium batteries help to re...
# 20  ‘Astonishing’ molecular syringe ferries protei...
# 21  Researchers in Germany protest proposed postdo...
# 22  COVID-origins report sparks debate over major ...
# 23  ‘Oumuamua enigma explained — and more of this ...
# 24  Antibody-patent row could have far-reaching im...
# 25  How green is your research? These scientists a...
# 26  JWST gets best view yet of planet in hotly pur...
# 27  Abel Prize: pioneer of ‘smooth’ physics wins t...
# 28  COVID-origins study links raccoon dogs to Wuha...
# 29               GPT-4 is here: what scientists think
# 30                  How stem cells make a human brain
#
#                                                  link  \
# 0   https://www.nature.com/articles/d41586-023-010...
# 1   https://www.nature.com/articles/d41586-023-010...
# 2   https://www.nature.com/articles/d41586-023-010...
# 3   https://www.nature.com/articles/d41586-023-009...
# 4   https://www.nature.com/articles/d41586-023-009...
